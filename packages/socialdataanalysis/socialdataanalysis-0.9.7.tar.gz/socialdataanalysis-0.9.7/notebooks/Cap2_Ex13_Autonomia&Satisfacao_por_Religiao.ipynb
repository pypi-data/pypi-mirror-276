# %% [markdown]
# # Aplicações práticas
#
# # 2.13 Exercício 13: Associação entre Autonomia e Satisfação por Religião
#
# ## A. Enunciado
#
# Baseando-se em um estudo transversal realizado em 2024, por meio de um questionário aplicado a uma amostra aleatória de 353 idosos que vivem em suas casas, seja sozinhos ou acompanhados, busca-se analisar a associação entre autonomia no desempenho de tarefas rotineiras (0. Não tem, 1. Tem) e a satisfação com a vida (0. Não tem, 1. Tem). Suspeita-se que a condição de ser ou não católico (0. Não católico, 1. Católico) possa influenciar a relação entre a autonomia e a satisfação com a vida. Portanto, pretende-se controlar o efeito da religião, utilizando-a como uma camada (Layer) no SPSS. Os dados obtidos estão presentes na linha "Count" da Tabela 1 e no arquivo "cap02-Autonomia Satisfação e Religiao.sav" do IBM-SPSS e também estão organizados em um dicionário em Python. As variáveis são consideradas nominais, pois são definidas unicamente por seus nomes.

# %% [markdown]
# # Resolução em Python

# %% [markdown]
# ## Carregando Bibliotecas

# %%
import pandas as pd  # Fornece DataFrames e Series para manipulação de dados em Python, facilitando operações como leitura, escrita, e manipulação de estruturas de dados tabulares.

# %% [markdown]
# ## Funções Personalizadas

# %%
import sys

# Adicionar o caminho do diretório ao sys.path
sys.path.append(r"C:\Users\ricar\OneDrive\Área de Trabalho\Livro\Cap_02\socialdataanalysis")

from association import gerar_tabela_contingencia
from association import analisar_frequencias_esperadas
from association import complementar_tabela_contingencia_com_analise_estatistica
from association import calcular_odds_ratio_razao_risco_discrepancia
from association import complementar_e_filtrar_tabelas_contingencia
from association import avaliar_homogeneidade_odds_ratio
from association import eliminacao_reversa_com_comparacao_llm
from association import calcular_e_exibir_odds_ratios_llm
from association import criar_tabela_contingencia_expandida_llm

# %% [markdown]
# ## Dados Fornecidos

# %%
# Dicionário com dados categorizados representando grupos e suas frequências
dados = {
    'Religião': [0, 0, 0, 0, 
                 1, 1, 1, 1],
    'Autonomia': [0, 0, 1, 1, 
                  0, 0, 1, 1],
    'Satisfação': [0, 1, 0, 1, 
                   0, 1, 0, 1],
    'Freq': [20, 39, 28, 25, 
             65, 58, 43, 75]
}

# Criando o DataFrame a partir do dicionário
dados = pd.DataFrame(dados)

# Convertendo as colunas para inteiros, se necessário
dados = dados.astype(int)

# Visualizando o dataframe
display(dados)
# Out:
#    Religião  Autonomia  Satisfação  Freq
# 0         0          0           0    20
# 1         0          0           1    39
# 2         0          1           0    28
# 3         0          1           1    25
# 4         1          0           0    65
# 5         1          0           1    58
# 6         1          1           0    43
# 7         1          1           1    75

# %% [markdown]
# ## Tabela 1: Tabela de Contingência

# %%
# Obter automaticamente os nomes dos grupos e da coluna de frequência
grupos = dados.columns[:-1].tolist()  # Todos exceto a última coluna
categorias = {
    grupos[0]: ['0. Não católico', '1. Católico'],
    grupos[1]: ['0. Não tem', '1. Tem'],
    grupos[2]: ['0. Não tem', '1. Tem'],
}

tabela_contingencia = gerar_tabela_contingencia(dados, grupos, categorias)

display(tabela_contingencia)
# Out:
# Satisfação                  0. Não tem  1. Tem
# Religião        Autonomia
# 0. Não católico 0. Não tem          20      39
#                 1. Tem              28      25
# 1. Católico     0. Não tem          65      58
#                 1. Tem              43      75

# %% [markdown]
# ## Tabela de Contingência com Cálculos

# %%
complementar_e_filtrar_tabelas_contingencia(tabela_contingencia, complementar_tabela_contingencia_com_analise_estatistica)
# Out:
# Satisfação                                    0. Não tem 1. Tem  Total
# Religião        Autonomia
# 0. Não católico 0. Não tem Count                    20.0   39.0   59.0
#                            Expected Count           25.3   33.7   59.0
#                            % within Autonomia       33.9   66.1  100.0
#                 1. Tem     Count                    28.0   25.0   53.0
#                            Expected Count           22.7   30.3   53.0
#                            % within Autonomia       52.8   47.2  100.0
#                 Total      Count                    48.0   64.0  112.0
#                            Expected Count           48.0   64.0  112.0
#                            % within Autonomia       42.9   57.1  100.0
# 1. Católico     0. Não tem Count                    65.0   58.0  123.0
#                            Expected Count           55.1   67.9  123.0
#                            % within Autonomia       52.8   47.2  100.0
#                 1. Tem     Count                    43.0   75.0  118.0
#                            Expected Count           52.9   65.1  118.0
#                            % within Autonomia       36.4   63.6  100.0
#                 Total      Count                   108.0  133.0  241.0
#                            Expected Count          108.0  133.0  241.0
#                            % within Autonomia       44.8   55.2  100.0
# Total           0. Não tem Count                    85.0   97.0  182.0
#                            Expected Count           80.4  101.6  182.0
#                            % within Autonomia       46.7   53.3  100.0
#                 1. Tem     Count                    71.0  100.0  171.0
#                            Expected Count           75.6   95.4  171.0
#                            % within Autonomia       41.5   58.5  100.0
#                 Total      Count                   156.0  197.0  353.0
#                            Expected Count          156.0  197.0  353.0
#                            % within Autonomia       44.2   55.8  100.0

# %% [markdown]
# <font color="blue">
#
# ### 2.13.1. Pressupostos dos testes do Qui-Quadrado
# </font>

# %% [markdown]
# <font color="blue">
#
# #### a) Verificar a observância dos pressupostos dos testes do Qui-Quadrado.
# </font>

# %%
analisar_frequencias_esperadas(tabela_contingencia)
# Out:
# Análise para: 0. Não católico
#
#
# Fo: Satisfação  0. Não tem  1. Tem
# Autonomia
# 0. Não tem          20      39
# 1. Tem              28      25
#
# Fe: Satisfação  0. Não tem  1. Tem
# Autonomia
# 0. Não tem        25.3    33.7
# 1. Tem            22.7    30.3
#
#  a. 0 células (0.00%) têm uma frequência esperada menor que 5. A frequência esperada mínima é 22.71.
# ----------------------------------------------------------------------------------------------------
#
# Análise para: 1. Católico
#
#
# Fo: Satisfação  0. Não tem  1. Tem
# Autonomia
# 0. Não tem          65      58
# 1. Tem              43      75
#
# Fe: Satisfação  0. Não tem  1. Tem
# Autonomia
# 0. Não tem        55.1    67.9
# 1. Tem            52.9    65.1
#
#  a. 0 células (0.00%) têm uma frequência esperada menor que 5. A frequência esperada mínima é 52.88.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# <font color="blue">
#
# ### 2.13.2. Efeito interativo e hipóteses
# </fonte>

# %% [markdown]
# <font color="blue">
#
# #### b) A homogeneidade, ou seja, verificar a existência de um comportamento semelhante da autonomia segundo a satisfação com a vida conforme a religião dos idosos.
# </font>

# %%
complementar_e_filtrar_tabelas_contingencia(tabela_contingencia, calcular_odds_ratio_razao_risco_discrepancia)
# Out:
#                                                                 Value
# Religião
# 0. Não católico Odds Ratio for Autonomia (0. Não tem / 1. Tem)  0.458  \
#                 RR (ou RP) for Satisfação = 0. Não tem          0.642
#                 RR (ou RP) for Satisfação = 1. Tem              1.401
#                 N. of Valid Cases                                 112
# 1. Católico     Odds Ratio for Autonomia (0. Não tem / 1. Tem)  1.955
#                 RR (ou RP) for Satisfação = 0. Não tem          1.450
#                 RR (ou RP) for Satisfação = 1. Tem              0.742
#                 N. of Valid Cases                                 241
# Total           Odds Ratio for Autonomia (0. Não tem / 1. Tem)  1.234
#                 RR (ou RP) for Satisfação = 0. Não tem          1.125
#                 RR (ou RP) for Satisfação = 1. Tem              0.911
#                 N. of Valid Cases                                 353
#
#                                                                95% CI Lower
# Religião
# 0. Não católico Odds Ratio for Autonomia (0. Não tem / 1. Tem)        0.214  \
#                 RR (ou RP) for Satisfação = 0. Não tem                0.414
#                 RR (ou RP) for Satisfação = 1. Tem                    0.999
#                 N. of Valid Cases
# 1. Católico     Odds Ratio for Autonomia (0. Não tem / 1. Tem)        1.167
#                 RR (ou RP) for Satisfação = 0. Não tem                1.084
#                 RR (ou RP) for Satisfação = 1. Tem                    0.588
#                 N. of Valid Cases
# Total           Odds Ratio for Autonomia (0. Não tem / 1. Tem)        0.810
#                 RR (ou RP) for Satisfação = 0. Não tem                0.888
#                 RR (ou RP) for Satisfação = 1. Tem                    0.757
#                 N. of Valid Cases
#
#                                                                95% CI Upper
# Religião
# 0. Não católico Odds Ratio for Autonomia (0. Não tem / 1. Tem)        0.982
#                 RR (ou RP) for Satisfação = 0. Não tem                0.994
#                 RR (ou RP) for Satisfação = 1. Tem                    1.966
#                 N. of Valid Cases
# 1. Católico     Odds Ratio for Autonomia (0. Não tem / 1. Tem)        3.274
#                 RR (ou RP) for Satisfação = 0. Não tem                1.940
#                 RR (ou RP) for Satisfação = 1. Tem                    0.935
#                 N. of Valid Cases
# Total           Odds Ratio for Autonomia (0. Não tem / 1. Tem)        1.880
#                 RR (ou RP) for Satisfação = 0. Não tem                1.424
#                 RR (ou RP) for Satisfação = 1. Tem                    1.097
#                 N. of Valid Cases

# %%
avaliar_homogeneidade_odds_ratio(tabela_contingencia)
# Out:
# Teste de Breslow-Day:
# Chi-Squared: 9.7065
# Asymp. Sig. (2-sided): 0.0018
#
# Teste de Tarone:
# Chi-Squared: 9.7057
# Asymp. Sig. (2-sided): 0.0018

# %% [markdown]
# <font color="blue">
#
# ### 2.13.3. Modelo loglinear
# </fonte>

# %% [markdown]
# <font color="blue">
#
# #### c) A exploração do modelo loglinear que melhor define a associação entre as variáveis, por se ter violado a hipótese de homogeneidade.
#
# </font>

# %%
satured_model, adjusted_model = eliminacao_reversa_com_comparacao_llm(dados, display_models=True, compare_models=False)
# Out:
# Modelo Saturado:
#                   Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   Freq   No. Observations:                    8
# Model:                            GLM   Df Residuals:                        0
# Model Family:                 Poisson   Df Model:                            7
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -22.132
# Date:                Sat, 25 May 2024   Deviance:                  -1.0880e-14
# Time:                        20:05:05   Pearson chi2:                 4.69e-20
# No. Iterations:                     4   Pseudo R-squ. (CS):             0.9997
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         2.9957      0.224     13.397      0.000       2.557       3.434
# Religião                          1.1787      0.256      4.609      0.000       0.677       1.680
# Autonomia                         0.3365      0.293      1.149      0.250      -0.237       0.910
# Satisfação                        0.6678      0.275      2.428      0.015       0.129       1.207
# Religião:Autonomia               -0.7497      0.353     -2.126      0.034      -1.441      -0.058
# Religião:Satisfação              -0.7818      0.329     -2.376      0.018      -1.427      -0.137
# Autonomia:Satisfação             -0.7812      0.389     -2.008      0.045      -1.544      -0.019
# Religião:Autonomia:Satisfação     1.4514      0.470      3.090      0.002       0.531       2.372
# =================================================================================================
# Passo 1: Removendo Autonomia com p-valor 0.250
# Passo 2: Removendo Autonomia:Satisfação com p-valor 0.083
# Passo 3: Removendo Satisfação com p-valor 0.132
# Passo 4: Removendo Religião:Satisfação com p-valor 0.528
#
# Modelo Ajustado:
#                   Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   Freq   No. Observations:                    8
# Model:                            GLM   Df Residuals:                        4
# Model Family:                 Poisson   Df Model:                            3
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -25.691
# Date:                Sat, 25 May 2024   Deviance:                       7.1191
# Time:                        20:05:06   Pearson chi2:                     7.33
# No. Iterations:                     4   Pseudo R-squ. (CS):             0.9992
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         3.3322      0.094     35.265      0.000       3.147       3.517
# Religião                          0.7868      0.131      6.024      0.000       0.531       1.043
# Religião:Autonomia               -0.3578      0.177     -2.020      0.043      -0.705      -0.011
# Religião:Autonomia:Satisfação     0.5563      0.191      2.908      0.004       0.181       0.931
# =================================================================================================

# %% [markdown]
# <font color="blue">
#
# #### d) A confirmação do modelo escolhido e significância associação, usando os testes de independência condicional.
# </font>

# %%
# dados = # Aqui você precisa definir ou carregar seu DataFrame
satured_model, adjusted_model = eliminacao_reversa_com_comparacao_llm(dados, display_models=False, compare_models=True)
# Out:
# Comparação entre Modelos Saturado e Ajustado:
#
# AIC Modelo Saturado: 60.26
# AIC Modelo Ajustado: 59.38
#
# Teste de Razão de Verossimilhança (LRT):
#
# LR stat: 7.119, Diferença no Número de Parâmetros: 4, p-value: 0.130

# %% [markdown]
# <font color="blue">
#
# #### e) A intensidade da associação, através do odds rácio condicionado.
# </font>

# %%
calcular_e_exibir_odds_ratios_llm(adjusted_model)
# Out:
# Odds Ratios (ORs) e Intervalos de Confiança (ICs) de 95%:
#
# --------------------------------------------------------------------------------
# Intercept: OR=28.000, IC 95%=(23.266, 33.697)
# --------------------------------------------------------------------------------
# Religião: OR=2.196, IC 95%=(1.700, 2.837)
# --------------------------------------------------------------------------------
# Religião:Autonomia: OR=0.699, IC 95%=(0.494, 0.989)
# --------------------------------------------------------------------------------
# Religião:Autonomia:Satisfação: OR=1.744, IC 95%=(1.199, 2.538)
# --------------------------------------------------------------------------------

# %%
criar_tabela_contingencia_expandida_llm(dados, grupos, categorias, adjusted_model)
# Out:
#                            observed            expected            residuals
#                              1. Tem 0. Não tem   1. Tem 0. Não tem    1. Tem
# Religião        Autonomia
# 1. Católico     1. Tem           20         39     28.0       28.0      -8.0  \
#                 0. Não tem       28         25     28.0       28.0       0.0
# 0. Não católico 1. Tem           65         58     61.5       61.5       3.5
#                 0. Não tem       43         75     43.0       75.0       0.0
#
#
#                            0. Não tem
# Religião        Autonomia
# 1. Católico     1. Tem           11.0
#                 0. Não tem       -3.0
# 0. Não católico 1. Tem           -3.5
#                 0. Não tem        0.0
