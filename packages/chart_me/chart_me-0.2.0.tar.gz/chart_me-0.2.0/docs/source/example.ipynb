# %% [markdown]
# # Usage

# %%
import random
import pandas as pd
import chart_me as ce
print(f"chart_me version is {ce.__version__}")
# Out:
# chart_me version is 0.1.4

# %%
#mocking data for example
data = {
    "string_low_card": [random.choice(['stringA', 'stringB', 'stringC']) for _ in range(1000)],
    "floaties": [random.random() for i in range(1000)]
}
df = pd.DataFrame(data)
df.shape
# Out:
# (1000, 2)

# %%
ce.chart_me(df, 'string_low_card', 'floaties')
# Out:
# alt.Chart(...)
# alt.Chart(...)
